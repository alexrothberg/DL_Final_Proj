# %%
# pip installs
# !pip3 install pretty_midi
# Out:
# Requirement already satisfied: pretty_midi in /usr/local/lib/python3.7/site-packages (0.2.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/site-packages (from pretty_midi) (1.12.0)
# Requirement already satisfied: mido>=1.1.16 in /usr/local/lib/python3.7/site-packages (from pretty_midi) (1.2.9)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/site-packages (from pretty_midi) (1.17.1)

# %%
# imports
import pretty_midi
import os
import numpy as np

# %%
# Load MIDI file into PrettyMIDI object
def extract_pitches_vels_durations(filename):
    midi_data = pretty_midi.PrettyMIDI(filename)
    # Extract Piano
    piano_midi = midi_data.instruments[0]
    # Extract pitches in a list
    pitches = list(map(lambda x: x.pitch,piano_midi.notes))
    # Extract velocities in a list
    vels = list(map(lambda x: x.velocity,piano_midi.notes))
    durations = list(map(lambda x: x.end - x.start, piano_midi.notes))
    starts =  list(map(lambda x: x.start, piano_midi.notes))
    ends =  list(map(lambda x: x.end, piano_midi.notes))
    
    return(pitches,vels,durations,starts,ends)

# %%
# takes in a folder that contains midi files
# returns a tuple of (list of pitches list, list of velocities list, list of durations list)
# 
def extract_pitch_vel_duration_lists_for_folder(folder):
    pitches_list = []
    vels_list = []
    durations_list = []
    starts = []
    ends = []
    for song in os.listdir(folder):    
        print(song)
        if 'mid' in song:
            song_data = extract_pitches_vels_durations(folder + '/' + song)
            pitches_list.append(song_data[0])
            vels_list.append(song_data[1])
            durations_list.append(song_data[2])
            starts.append(song_data[3])
            ends.append(song_data[4])
            
    return(pitches_list,vels_list,durations_list,starts,ends)

# %%
all_jazz_data = extract_pitch_vel_duration_lists_for_folder('jazz')
# Out:
# Chelsea Bridge.mid
# Blue_In_Green.mid
# songfor.mid
# Very Early solo piano.mid
# alone.mid
# dearlybeloved.mid
# shinystockings.mid
# olddevilmoon.mid
# daybyday.mid
# I Fall in Love v2.mid
# TheOddCpl.mid
# IfIwere.mid
# Have You Met - duet.mid
# joyed.mid
# I_Wont_Dance_R.mid
# stiltime.mid
# broadway.mid
# Mnksmd.mid
# Falling in Love with Love trio.mid
# sonata4vc.mid
# Justfren.mid
# Come Rain or Come Shine duo.mid
# shiny.mid
# moanin.mid
# All The Things You Are.mid
# Day Dream.mid
# MyFoolishHeart.mid
# Long Ago and Far away - 3 versions.mid
# something wonderful.mid
# grooving_hard.mid
# Where is Love - solo.mid
# AutumnL.mid
# budo.mid
# Cast Your Fate.mid
# Mad About the Boy.mid
# Ladies in Mercedes.mid
# GrooveYard.mid
# Its theTalk Of The Town - solo.mid
# Zingaro - Jobim.mid
# Shenandoah.mid
# world.mid
# Alabama.mid
# StWeather.mid
# Thingsaintwhattheyusedtobe.mid
# along.mid
# HowkumU.mid
# xmas.mid
# lovercome piano.mid
# Its Easy to Remember.mid
# I Thought About You (Doug McKenzie).mid
# Over the rain trio.mid
# Sweetlorraine.mid
# On Green Dolphin 4.mid
# Love walked In.mid
# blues4npage.mid
# Old Man River.mid
# It Could Happen - piano trio.mid
# AHouseis.mid
# turnoutthestars.mid
# Aliceinw.mid
# FreckleFace.mid
# Green Dolph solo.mid
# billiesb.mid
# bluesette.mid
# myheartstoodstill edited a bit.mid
# comerain.mid
# rndmngt.mid
# ARemarkYouMade.mid
# This Time the Dreams on Me.mid
# Nutville.mid
# whydidi.mid
# I Hear a Rhapsody.mid
# funkallero.mid
# LushLife  trio.mid
# tunisia.mid
# It_sAlmostLikeBeingInLove.mid
# I Concentrate on You.mid
# Moon and Sand.mid
# Witchcraft.mid
# Zip-A-Dee-Doo-Dah.mid
# ForSentimentalReasons.mid
# Come Rain or Come Shine V1.mid
# grelots.mid
# It Could Happen V2.mid
# When I Fall in Love.mid
# cinema.mid
# MyFunny3.mid
# atrain2.mid
# DancingontheCeiling.mid
# ISaidItbefore.mid
# Prelude to a kiss.mid
# Gone with the wind.mid
# youtookadvantageofme.mid
# Goin__Home_(Real_Time)_(Antonin_Dvorak).mid
# My Romance.mid
# prelude.mid
# Itdon_tmeanathing.mid
# TheManThatGotAway.mid
# Bess You Is.mid
# OurLove_x.mid
# Spring Is Here - Bill Evans chords.mid
# ItCouldHappenGM.mid
# sixteengoing.mid
# Sweet1.mid
# YBSN2CH2.mid
# Clifford1.mid
# youdbe.mid
# bdazhed.mid
# alfiepno.mid
# Yesterday.mid
# My Shining Hour.mid
# moonlightinvermont.mid
# TheSongisYoutrio.mid
# stella2.mid
# dolphindance3.mid
# manteca.mid
# TakinAC.mid
# taketheatrain.mid
# peanutsg.mid
# StrangeMeadowlark.mid
# EasytoLove2.mid
# pentupHouse.mid
# comesun.mid
# move.mid
# birdland.mid
# Two For The Road 5.mid
# What is there to say.mid
# ontheotherhand.mid
# Some day My Prince.mid
# sonnymoo.mid
# sentmood.mid
# simplelife.mid
# Brazillike.mid
# Out of Nowhere 1.mid
# Lovewalkedin.mid
# 4thAvenueTheme.mid
# That Ole Devil Called Love.mid
# speaklo3.mid
# Beautiful Love (Doug McKenzie).mid
# Basiervg.mid
# cjamblusx.mid
# beacon.mid
# fever2.mid
# Cubano Chant 2.mid
# Out of Nowhere 3.mid
# Bluenboo.mid
# tunisia2.mid
# cherokee.mid
# Desafinado.mid
# You Are So Beautiful The Grand.mid
# Surrey medley.mid
# ladybegood.mid
# Baby its Cold outside.mid
# Mood Indigo - solo.mid
# Spring is Here 2 (K Barron).mid
# HushABye.mid
# BigMess.mid
# Out of Nowhere 2.mid
# bewitched.mid
# Detour ahead.mid
# whispernot.mid
# nardis2.mid
# LBirdland.mid
# maidenvoyage.mid
# Renewaltrio.mid
# IALikeBeingInLove.mid
# Warmvalleysolo.mid
# santa.mid
# chromBlinF.mid
# But Beautifulsolo.mid
# Have You Met Miss Jones - latin.mid
# IfIshouldLeaveYou.mid
# AutumnLeaves.mid
# SoinLovesolo.mid
# don-lee2.mid
# my1aonly.mid
# Some Other Time.mid
# flybynight.mid
# JoySpring.mid
# stolen.mid
# Serenata solo.mid
# DolphinDance.mid
# TheDuke.mid
# Time remembered.mid
# SweetAndLovely.mid
# McKenzie-secret love.mid
# Make Someone Happy.mid
# DstMeT.mid
# Dannyboy.mid
# if i loved you.mid
# quick.mid
# If_bell.mid
# Bymyself.mid
# stormyweather.mid
# TooYoungtogoSteady.mid
# Indiana.mid
# BluesForTrane.mid
# Desafinado78.mid
# KingandI.mid
# autleave.mid
# DaysOf.mid
# TheManILove.mid
# Peanut Vendor (El Manisero).mid
# Just Friends Trio.mid
# laura.mid
# DeepPurple.mid
# By Myself3.mid
# Anthropology.mid
# Remember - solo jazz piano.mid
# foreplayx.mid
# Beautiful_Love.mid
# riofunk.mid
# Chameleon.mid
# solar.mid
# gonewind.mid
# Pick yourself.mid
# lazybird.mid
# conalma.mid
# moreicu.mid
# Blameiton.mid
# The End of a Love Affair.mid
# Blue room midi file.mid
# youhavechanged.mid
# Taking a Chance On Love - Solo piano.mid
# porgy2.mid
# WWHappens.mid
# atIknew.mid
# Hymn To Freedom.mid
# merryxmas.mid
# They say its wonderful.mid
# Autumn In NY.mid
# send in the clowns.mid
# BlueTrain.mid
# Exactly Like You.mid
# hayBurner.mid
# Icantgetstarted.mid
# star eyes.mid
# porgy1.mid
# Young and Foolish.mid
# WhyDoILoveYou.mid
# NoMoreBlues.mid
# toss_up.mid
# Strollin_.mid
# Just a Gigolo.mid
# killerjoe.mid
# Yesterdays1.mid
# phasedance.mid
# Aghostofachance.mid
# Isn_t_it_Romantic.mid
# I_m Confessin_ - solo.mid
# SophisticatedLady.mid
# shawnuff.mid
# BPowell.mid
# Old Folks.mid
# SammyWalked.mid
# israel.mid
# whisper.mid
# IConcOnY.mid
# AllOfMe2.mid
# estate.mid
# Bach Prelude No 1 (Ave Maria).mid
# LookfortheSilverLining.mid
# roofgdn2.mid
# LoveWalked.mid
# wylhg.mid
# Falling Grace .mid
# SoulEyessolo.mid
# desire.mid
# idmathing.mid
# justfrien solo.mid
# soon.mid
# McKenzie-Ishouldcare2.mid
# ICWABook.mid
# The Way You look trio.mid
# HOW.mid
# couldwrite.mid
# HaveUMMsJ.mid
# thiscantbelove.mid
# Cantabile 2.mid
# NewOrleans.mid
# SoInlove - trio version.mid
# sinceIfell.mid
# BrazilianSuite.mid
# thereisnogreaterlove.mid
# I_ll Close My Eyes 2.mid
# xtracrispy.mid
# eastofthesun.mid
# AllTheThings V2.mid
# dolphnst.mid
# four2.mid
# Tryalittle21.mid
# penthouse s.mid
# hwdptrio.mid
# satin_doll.mid
# ineverknew.mid
# Myoneand.mid
# mwv_blues.mid
# ishouldcare2.mid
# I Cover the Waterfront - solo.mid
# I fall in Love Too Easily.mid
# Spring Is Here2-Bill Evans chords.mid
# broadwa2.mid
# alltheth.mid
# maisquenada.mid
# Begin The Beguine.mid
# Ask Me Now 2.mid
# sushi.mid
# angela.mid
# Dreamsville.mid
# Speak Low (Doug McKenzie).mid
# periscope.mid
# Isfahan (Elf).mid
# bl4alice.mid
# AllTheThings Reharmonized.mid
# nica.mid
# afine-1.mid
# timerem2.mid
# Time after Time 2.mid
# eyeotbeh.mid
# Since We Met Jazz Kit.mid
# Danny Boy.mid
# accustomed.mid
# TakinACh.mid
# SatinDol.mid
# Idkwhtime.mid
# caravan.mid
# Gaviota trio 2.mid
# Effendi - McCoy Tyner.mid
# There will never be another you.mid
# Easy Living 3.mid
# howdsolo.mid
# MembersOnly.mid
# bethlehem.mid
# Memories of Paris.mid
# peace.mid
# MyShiningHoursolo.mid
# The Masquerade is Over.mid
# Cute.mid
# Pure Imagination.mid
# Nicadream.mid
# afine-2.mid
# youdontknow trio.mid
# NARDIS.mid
# Do I Love You Because you_re Beautiful.mid
# IGrownAcc2HF.mid
# A Sleepin_ Bee.mid
# Little Girl Blue.mid
# Summer wind 2.mid
# INVITATION.mid

# %%
first_song = (all_jazz_data[0][0],all_jazz_data[1][0],all_jazz_data[3][0],all_jazz_data[4][0])

# %%
print(len(all_jazz_data[3][1]))
# Out:
# 1462

# %%
def recreate_song_from_data(pitches,vels,starts,ends,name):
    recreated_song = pretty_midi.PrettyMIDI()
    # Create an Instrument instance for a cello instrument
    song_program = pretty_midi.instrument_name_to_program('Acoustic Grand Piano')
    piano = pretty_midi.Instrument(program=song_program)
    # Iterate over note names, which will be converted to note number later
    for i in range (0,len(vels)):
        note = pretty_midi.Note(velocity=vels[i], pitch=pitches[i], start=starts[i], end=ends[i])
        piano.notes.append(note)

    recreated_song.instruments.append(piano)
    # Write out the MIDI data
    recreated_song.write(name + '.mid')

# %%
recreate_song_from_data(first_song[0],first_song[1],first_song[2],first_song[3], "TESTJAZZ2")

# %%
print(first_song[0])
# Out:
# [82, 58, 84, 60, 85, 61, 87, 63, 89, 65, 91, 67, 92, 93, 39, 46, 60, 65, 69, 72, 77, 81, 84, 91, 93, 92, 55, 61, 94, 91, 63, 67, 70, 53, 59, 63, 53, 58, 67, 59, 70, 53, 59, 63, 67, 58, 70, 63, 58, 53, 59, 67, 67, 58, 63, 70, 59, 53, 89, 49, 91, 54, 90, 55, 56, 92, 89, 85, 93, 81, 60, 65, 55, 61, 94, 58, 83, 91, 79, 87, 63, 59, 92, 53, 46, 74, 59, 58, 62, 56, 67, 74, 79, 70, 71, 82, 83, 96, 92, 95, 94, 93, 92, 91, 90, 39, 54, 89, 101, 97, 65, 61, 97, 97, 97, 65, 61, 58, 54, 97, 98, 99, 100, 32, 44, 101, 104, 98, 93, 89, 64, 60, 89, 54, 89, 89, 63, 53, 85, 60, 56, 85, 65, 80, 80, 73, 63, 73, 60, 73, 63, 53, 58, 73, 82, 94, 58, 96, 84, 60, 85